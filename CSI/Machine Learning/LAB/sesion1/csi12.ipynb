# %% [markdown]
# ### Load iris data

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pylab as plt

iris = pd.read_csv('data/iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
list(iris)
# Out:
# ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']

# %% [markdown]
# ### Define frames for the three classes

# %%
setosa = iris[iris.Species=='Iris-setosa']
versicolor = iris[iris.Species=='Iris-versicolor']
virginica = iris[iris.Species=='Iris-virginica']

# %%
print("setosa: {} flowers; versicolor: {} flowers; virginica: {} flowers.".format(setosa.shape, versicolor.shape, virginica.shape))
# Out:
# setosa: (50, 5) flowers; versicolor: (50, 5) flowers; virginica: (50, 5) flowers.

# %% [markdown]
# ### Plot scatter plot with colors according to labels

# %%
s = plt.plot(setosa['SepalLength'],setosa['PetalLength'],'bo')
vi = plt.plot(virginica['SepalLength'],virginica['PetalLength'],'go')
ve = plt.plot(versicolor['SepalLength'],versicolor['PetalLength'],'ro')
lx = ve[0].axes.set_xlabel('Sepal Length')
ly = ve[0].axes.set_ylabel('Petal Length')

# %%
s = plt.plot(setosa['SepalWidth'],setosa['PetalWidth'],'bo')
vi = plt.plot(virginica['SepalWidth'],virginica['PetalWidth'],'go')
ve = plt.plot(versicolor['SepalWidth'],versicolor['PetalWidth'],'ro')
lx = ve[0].axes.set_xlabel('Sepal Width')
ly = ve[0].axes.set_ylabel('Petal Width')

# %% [markdown]
# ### Split data into train and test set

# %%
from sklearn.model_selection import train_test_split
attributes = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
X = iris[attributes]
y = iris['Species']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [markdown]
# ### Learn something...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 3)

# %% [markdown]
# ### Train the classifier with the training data

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Predict using kNN

# %%
df = pd.DataFrame(data=X_test, columns=attributes)
df['true class'] = y_test
df['kNN_pred'] = knn.predict(X_test)
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth       true class  \
# 114          5.8         2.8          5.1         2.4   Iris-virginica
# 62           6.0         2.2          4.0         1.0  Iris-versicolor
# 33           5.5         4.2          1.4         0.2      Iris-setosa
# 107          7.3         2.9          6.3         1.8   Iris-virginica
# 7            5.0         3.4          1.5         0.2      Iris-setosa
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 40           5.0         3.5          1.3         0.3      Iris-setosa
# 86           6.7         3.1          4.7         1.5  Iris-versicolor
# 76           6.8         2.8          4.8         1.4  Iris-versicolor
# 71           6.1         2.8          4.0         1.3  Iris-versicolor
# 134          6.1         2.6          5.6         1.4   Iris-virginica
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 73           6.1         2.8          4.7         1.2  Iris-versicolor
# 54           6.5         2.8          4.6         1.5  Iris-versicolor
# 63           6.1         2.9          4.7         1.4  Iris-versicolor
# 37           4.9         3.1          1.5         0.1      Iris-setosa
# 78           6.0         2.9          4.5         1.5  Iris-versicolor
# 90           5.5         2.6          4.4         1.2  Iris-versicolor
# 45           4.8         3.0          1.4         0.3      Iris-setosa
# 16           5.4         3.9          1.3         0.4      Iris-setosa
# 121          5.6         2.8          4.9         2.0   Iris-virginica
# 66           5.6         3.0          4.5         1.5  Iris-versicolor
# 24           4.8         3.4          1.9         0.2      Iris-setosa
# 8            4.4         2.9          1.4         0.2      Iris-setosa
# 126          6.2         2.8          4.8         1.8   Iris-virginica
# 22           4.6         3.6          1.0         0.2      Iris-setosa
# 44           5.1         3.8          1.9         0.4      Iris-setosa
# 97           6.2         2.9          4.3         1.3  Iris-versicolor
# 93           5.0         2.3          3.3         1.0  Iris-versicolor
# 26           5.0         3.4          1.6         0.4      Iris-setosa
# 137          6.4         3.1          5.5         1.8   Iris-virginica
# 84           5.4         3.0          4.5         1.5  Iris-versicolor
# 27           5.2         3.5          1.5         0.2      Iris-setosa
# 127          6.1         3.0          4.9         1.8   Iris-virginica
# 132          6.4         2.8          5.6         2.2   Iris-virginica
# 59           5.2         2.7          3.9         1.4  Iris-versicolor
# 18           5.7         3.8          1.7         0.3      Iris-setosa
# 83           6.0         2.7          5.1         1.6  Iris-versicolor
#
#             kNN_pred
# 114   Iris-virginica
# 62   Iris-versicolor
# 33       Iris-setosa
# 107   Iris-virginica
# 7        Iris-setosa
# 100   Iris-virginica
# 40       Iris-setosa
# 86   Iris-versicolor
# 76   Iris-versicolor
# 71   Iris-versicolor
# 134   Iris-virginica
# 51   Iris-versicolor
# 73   Iris-versicolor
# 54   Iris-versicolor
# 63   Iris-versicolor
# 37       Iris-setosa
# 78   Iris-versicolor
# 90   Iris-versicolor
# 45       Iris-setosa
# 16       Iris-setosa
# 121   Iris-virginica
# 66   Iris-versicolor
# 24       Iris-setosa
# 8        Iris-setosa
# 126   Iris-virginica
# 22       Iris-setosa
# 44       Iris-setosa
# 97   Iris-versicolor
# 93   Iris-versicolor
# 26       Iris-setosa
# 137   Iris-virginica
# 84   Iris-versicolor
# 27       Iris-setosa
# 127   Iris-virginica
# 132   Iris-virginica
# 59   Iris-versicolor
# 18       Iris-setosa
# 83    Iris-virginica

# %% [markdown]
# ### Estimate the accuracy of the classifier on future data, using the test data

# %%
knn.score(X_test, y_test)
# Out:
# 0.9736842105263158

# %% [markdown]
# ### What happens if we vary k?

# %%
k_range = [num for num in range(110) if num % 10 == 1]
print(k_range)
# Out:
# [1, 11, 21, 31, 41, 51, 61, 71, 81, 91, 101]

# %%
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    print("with {}-NN accuracy is {}".format(k, knn.score(X_test, y_test)))
# Out:
# with 1-NN accuracy is 0.9736842105263158
# with 11-NN accuracy is 0.9736842105263158
# with 21-NN accuracy is 0.9736842105263158
# with 31-NN accuracy is 0.9473684210526315
# with 41-NN accuracy is 0.8947368421052632
# with 51-NN accuracy is 0.8947368421052632
# with 61-NN accuracy is 0.8947368421052632
# with 71-NN accuracy is 0.6578947368421053
# with 81-NN accuracy is 0.631578947368421
# with 91-NN accuracy is 0.6052631578947368
# with 101-NN accuracy is 0.5789473684210527
